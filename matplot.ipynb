# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/user/miniconda/lib/python3.9/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/user/miniconda/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /home/user/miniconda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# importing library
import matplotlib.pyplot as plt
import numpy as np
 
# Data for plotting
x = np.arange(0.0, 2.0, 0.01)
y = 1 + np.sin(2 * np.pi * x)
 
# Creating 6 subplots and unpacking the output array immediately
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2)
ax1.plot(x, y, color="orange")
ax2.plot(x, y, color="green")
ax3.plot(x, y, color="blue")
ax4.plot(x, y, color="magenta")
ax5.plot(x, y, color="black")
ax6.plot(x, y, color="red")
